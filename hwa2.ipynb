# %% [markdown]
# # Exercise 2: Decision Trees
#
# In this assignment you will implement a Decision Tree algorithm as learned in class.
#
# ## Read the following instructions carefully:
#
# 1. This jupyter notebook contains all the step by step instructions needed for this exercise.
# 2. Write vectorized code whenever possible.
# 3. You are responsible for the correctness of your code and should add as many tests as you see fit. Tests will not be graded nor checked.
# 4. Write your functions in the provided `hw2.py` python module only. All the logic you write is imported and used in this jupyter notebook.
# 5. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/) and [numpy](https://www.numpy.org/devdocs/reference/) only. Any other imports detected in `hw2.py` will earn you the grade of 0, even if you only used them for testing.
# 6. Your code must run without errors. During the environment setup, you were given a specific version of `numpy` to install. Changes of the configuration we provided are at your own risk. Code that cannot run will also earn you the grade of 0.
# 7. Write your own code. Cheating will not be tolerated.
# 8. Submission includes the `hw2.py` file and this notebook. Answers to qualitative questions should be written in markdown cells (with $\LaTeX$ support).
# 9. You are allowed to include additional functions.
# 10. Submission: zip only the completed jupyter notebook and the python file `hw2.py`. Do not include the data or any directories. Name the file `ID1_ID2.zip` and submit only one copy of the assignment.
#
# ## In this exercise you will perform the following:
# 1. Practice OOP in python.
# 2. Implement two impurity measures: Gini and Entropy.
# 3. Implement a decision tree from scratch.
# 4. Prune the tree to achieve better results.
# 5. Visualize your results and the tree.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from hw2 import * # this imports all functions from hw2.

# make matplotlib figures appear inline in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Warmup - OOP in python
#
# Our decision tree will be implemented using a dedicated python class. Python classes are very similar to classes in Java.
#
#
# You can use the following [site](https://jeffknupp.com/blog/2014/06/18/improve-your-python-python-classes-and-object-oriented-programming/) to learn about classes in python.

# %%
class Node(object):
    def __init__(self, data):
        self.data = data
        self.children = []

    def add_child(self, node):
        self.children.append(node)

# %%
n = Node(5)
p = Node(6)
q = Node(7)
n.add_child(p)
n.add_child(q)
n.children
# Out:
# [<__main__.Node at 0x11eba3978>, <__main__.Node at 0x11eba39e8>]

# %% [markdown]
# ## Data preprocessing
#
# We will use the breast cancer dataset that is available as a part of sklearn - a popular machine learning and data science library in python. In this example, our dataset will be a single matrix with the **labels on the last column**. Notice that you are not allowed to use additional functions from sklearn.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# load dataset
X, y = datasets.load_breast_cancer(return_X_y = True)
X = np.column_stack([X,y]) # the last column holds the labels

# split dataset
X_train, X_test = train_test_split(X, random_state=99)

print("Training dataset shape: ", X_train.shape)
print("Testing dataset shape: ", X_test.shape)
# Out:
# Training dataset shape:  (426, 31)
# Testing dataset shape:  (143, 31)

# %% [markdown]
# ## Impurity Measures
#
# Implement the functions `calc_gini` (5 points) and `calc_entropy` (5 points) in the python file `hw2.py`. You are encouraged to test your implementation using the cell below.

# %%
print("impurity by gini formula is:", calc_gini(X_train))
print("impurity by entropy formula is:",calc_entropy(X_train))
# Out:
# impurity by gini formula is: 0.47768299940488
# impurity by entropy formula is: 0.9675594819018212

# %% [markdown]
# ## Building a Decision Tree
#
# Use a Python class to construct the decision tree (look at the `DecisionNode` class in the python file `hw2.py`. Your class should support the following functionality:
#
# 1. Initiating a node for a decision tree. You will need to use several class methods and class attributes and you are free to use them as you see fit. We recommend that every node will hold the feature and value used for the split and its children.
# 2. Your code should support both Gini and Entropy as impurity measures.
# 3. The provided data includes continuous data. In this exercise, create at most a single split for each node of the tree. The threshold you need to use for this exercise are the average of each consecutive pair of values. For example, assume some features contains the following values: [1,2,3,4,5]. You should use the following thresholds [1.5, 2.5, 3.5, 4.5].
# 4. When constructing the tree, test all possible thresholds for each feature. The stopping criteria is a pure tree.
#
# Complete the class `DecisionNode` in the python file `hw2.py`. The structure of this class is entirely up to you. Complete the function `build_tree` in the python file `hw2.py`. This function should get the training dataset and the impurity as inputs, initiate a root for the decision tree and construct the tree according to the procedure you learned in class. (30 points).

# %%
# python support passing a function as arguments to another function.
a = DecisionNode(2,2)

a.best_threshold(2,X_train,calc_gini)
#tree_gini = build_tree(data=X_train, impurity=calc_gini) 
#tree_entropy = build_tree(data=X_train, impurity=calc_entropy)
# Out:
# the best bestThreshold is: 46.065
# the best bestThreshold gain is: -1
# 1
# 425
# the best bestThreshold is: 46.065
# the best bestThreshold gain is: 0.0007318809293208606
# 2
# 424
# the best bestThreshold is: 50.80500000000001
# the best bestThreshold gain is: 0.0014672141271759864
# 3
# 423
# the best bestThreshold is: 53.68000000000001
# the best bestThreshold gain is: 0.002206024077739843
# 4
# 422
# the best bestThreshold is: 54.215
# the best bestThreshold gain is: 0.002948335497263699
# 5
# 421
# the best bestThreshold is: 54.38
# the best bestThreshold gain is: 0.0036941733368328067
# 6
# 420
# the best bestThreshold is: 54.475
# the best bestThreshold gain is: 0.004443562785161725
# 7
# 419
# the best bestThreshold is: 54.595
# the best bestThreshold gain is: 0.005196529271430161
# 8
# 418
# the best bestThreshold is: 54.965
# the best bestThreshold gain is: 0.005953098468159224
# 9
# 417
# the best bestThreshold is: 55.55500000000001
# the best bestThreshold gain is: 0.006713296294129201
# 10
# 416
# the best bestThreshold is: 56.1
# the best bestThreshold gain is: 0.007477148917339416
# 11
# 415
# the best bestThreshold is: 57.55
# the best bestThreshold gain is: 0.008244682758010935
# 12
# 414
# the best bestThreshold is: 58.765
# the best bestThreshold gain is: 0.00901592449163241
# 13
# 413
# the best bestThreshold is: 58.9
# the best bestThreshold gain is: 0.00979090105205116
# 14
# 412
# the best bestThreshold is: 59.105000000000004
# the best bestThreshold gain is: 0.010569639634607941
# 15
# 411
# the best bestThreshold is: 59.230000000000004
# the best bestThreshold gain is: 0.011352167699318239
# 16
# 410
# the best bestThreshold is: 59.43
# the best bestThreshold gain is: 0.012138512974100235
# 17
# 409
# the best bestThreshold is: 59.78
# the best bestThreshold gain is: 0.012928703458049862
# 18
# 408
# the best bestThreshold is: 60.015
# the best bestThreshold gain is: 0.013722767424764082
# 19
# 407
# the best bestThreshold is: 60.09
# the best bestThreshold gain is: 0.01452073342571264
# 20
# 406
# the best bestThreshold is: 60.225
# the best bestThreshold gain is: 0.015322630293660933
# 21
# 405
# the best bestThreshold is: 60.535
# the best bestThreshold gain is: 0.0161284871461424
# 22
# 404
# the best bestThreshold is: 60.89
# the best bestThreshold gain is: 0.016938333388982596
# 23
# 403
# the best bestThreshold is: 61.055
# the best bestThreshold gain is: 0.017752198719876655
# 24
# 402
# the best bestThreshold is: 61.150000000000006
# the best bestThreshold gain is: 0.018570113132019006
# 25
# 401
# the best bestThreshold is: 61.365
# the best bestThreshold gain is: 0.019392106917787866
# 25
# 401
# the best bestThreshold is: 61.365
# the best bestThreshold gain is: 0.019392106917787866
# 27
# 399
# the best bestThreshold is: 61.565
# the best bestThreshold gain is: 0.02104845529813426
# 28
# 398
# the best bestThreshold is: 61.66
# the best bestThreshold gain is: 0.021882872007328802
# 29
# 397
# the best bestThreshold is: 61.805
# the best bestThreshold gain is: 0.022721492327149095
# 30
# 396
# the best bestThreshold is: 62.019999999999996
# the best bestThreshold gain is: 0.02356434810313013
# 31
# 395
# the best bestThreshold is: 62.305
# the best bestThreshold gain is: 0.024411471503293203
# 32
# 394
# the best bestThreshold is: 62.845
# the best bestThreshold gain is: 0.02526289502223894
# 33
# 393
# the best bestThreshold is: 63.474999999999994
# the best bestThreshold gain is: 0.026118651485301403
# 34
# 392
# the best bestThreshold is: 63.94
# the best bestThreshold gain is: 0.026978774052767274
# 35
# 391
# the best bestThreshold is: 64.265
# the best bestThreshold gain is: 0.027843296224158876
# 36
# 390
# the best bestThreshold is: 64.47999999999999
# the best bestThreshold gain is: 0.028712251842583192
# 37
# 389
# the best bestThreshold is: 64.57499999999999
# the best bestThreshold gain is: 0.029585675099148445
# 38
# 388
# the best bestThreshold is: 65.13499999999999
# the best bestThreshold gain is: 0.03046360053744862
# 39
# 387
# the best bestThreshold is: 65.75999999999999
# the best bestThreshold gain is: 0.03134606305811721
# 40
# 386
# the best bestThreshold is: 66.025
# the best bestThreshold gain is: 0.032233097923452636
# 41
# 385
# the best bestThreshold is: 66.36
# the best bestThreshold gain is: 0.0331247407621143
# 42
# 384
# the best bestThreshold is: 66.57
# the best bestThreshold gain is: 0.03402102757389408
# 43
# 383
# the best bestThreshold is: 66.67
# the best bestThreshold gain is: 0.034921994734560535
# 44
# 382
# the best bestThreshold is: 66.77
# the best bestThreshold gain is: 0.035827679000780044
# 45
# 381
# the best bestThreshold is: 67.115
# the best bestThreshold gain is: 0.036738117515116187
# 46
# 380
# the best bestThreshold is: 67.44999999999999
# the best bestThreshold gain is: 0.03765334781110685
# 47
# 379
# the best bestThreshold is: 67.75
# the best bestThreshold gain is: 0.038573407818421945
# 48
# 378
# the best bestThreshold is: 68.26
# the best bestThreshold gain is: 0.03949833586810381
# 49
# 377
# the best bestThreshold is: 68.6
# the best bestThreshold gain is: 0.04042817069789012
# 50
# 376
# the best bestThreshold is: 68.91499999999999
# the best bestThreshold gain is: 0.04136295145762203
# 51
# 375
# the best bestThreshold is: 69.21000000000001
# the best bestThreshold gain is: 0.0423027177147392
# 52
# 374
# the best bestThreshold is: 69.715
# the best bestThreshold gain is: 0.04324750945986228
# 53
# 373
# the best bestThreshold is: 70.23
# the best bestThreshold gain is: 0.04419736711246608
# 54
# 372
# the best bestThreshold is: 70.35
# the best bestThreshold gain is: 0.04515233152664283
# 55
# 371
# the best bestThreshold is: 70.4
# the best bestThreshold gain is: 0.046112443996960795
# 56
# 370
# the best bestThreshold is: 70.44
# the best bestThreshold gain is: 0.04707774626441563
# 57
# 369
# the best bestThreshold is: 70.57
# the best bestThreshold gain is: 0.048048280522479836
# 58
# 368
# the best bestThreshold is: 70.73
# the best bestThreshold gain is: 0.04902408942325104
# 58
# 368
# the best bestThreshold is: 70.73
# the best bestThreshold gain is: 0.04902408942325104
# 60
# 366
# the best bestThreshold is: 70.83000000000001
# the best bestThreshold gain is: 0.05099170409201936
# 61
# 365
# the best bestThreshold is: 70.89500000000001
# the best bestThreshold gain is: 0.05198359751408316
# 62
# 364
# the best bestThreshold is: 70.935
# the best bestThreshold gain is: 0.0529809409000046
# 63
# 363
# the best bestThreshold is: 71.095
# the best bestThreshold gain is: 0.05398377929080711
# 64
# 362
# the best bestThreshold is: 71.245
# the best bestThreshold gain is: 0.0549921582252052
# 65
# 361
# the best bestThreshold is: 71.315
# the best bestThreshold gain is: 0.05600612374649755
# 66
# 360
# the best bestThreshold is: 71.435
# the best bestThreshold gain is: 0.057025722409574875
# 66
# 360
# the best bestThreshold is: 71.435
# the best bestThreshold gain is: 0.057025722409574875
# 68
# 358
# the best bestThreshold is: 71.61
# the best bestThreshold gain is: 0.05908200798147928
# 69
# 357
# the best bestThreshold is: 71.745
# the best bestThreshold gain is: 0.06011879062277564
# 70
# 356
# the best bestThreshold is: 71.775
# the best bestThreshold gain is: 0.06116139788565228
# 71
# 355
# the best bestThreshold is: 71.795
# the best bestThreshold gain is: 0.06220987899226338
# 72
# 354
# the best bestThreshold is: 71.85
# the best bestThreshold gain is: 0.063264283720946
# 73
# 353
# the best bestThreshold is: 71.85
# the best bestThreshold gain is: 0.063264283720946
# 74
# 352
# the best bestThreshold is: 71.85
# the best bestThreshold gain is: 0.063264283720946
# 75
# 351
# the best bestThreshold is: 71.85
# the best bestThreshold gain is: 0.063264283720946
# 76
# 350
# the best bestThreshold is: 71.85
# the best bestThreshold gain is: 0.063264283720946
# 77
# 349
# the best bestThreshold is: 72.88
# the best bestThreshold gain is: 0.06418141160247298
# 78
# 348
# the best bestThreshold is: 73.00999999999999
# the best bestThreshold gain is: 0.06525870414911317
# 79
# 347
# the best bestThreshold is: 73.03999999999999
# the best bestThreshold gain is: 0.06634223016976332
# 80
# 346
# the best bestThreshold is: 73.11
# the best bestThreshold gain is: 0.06743204279818787
# 81
# 345
# the best bestThreshold is: 73.22
# the best bestThreshold gain is: 0.06852819582944636
# 82
# 344
# the best bestThreshold is: 73.28999999999999
# the best bestThreshold gain is: 0.06963074372673855
# 83
# 343
# the best bestThreshold is: 73.28999999999999
# the best bestThreshold gain is: 0.06963074372673855
# 83
# 343
# the best bestThreshold is: 73.28999999999999
# the best bestThreshold gain is: 0.06963074372673855
# 85
# 341
# the best bestThreshold is: 73.28999999999999
# the best bestThreshold gain is: 0.06963074372673855
# 86
# 340
# the best bestThreshold is: 73.455
# the best bestThreshold gain is: 0.06967159307359544
# 87
# 339
# the best bestThreshold is: 73.56
# the best bestThreshold gain is: 0.07079150975562926
# 88
# 338
# the best bestThreshold is: 73.64500000000001
# the best bestThreshold gain is: 0.07191812505929068
# 89
# 337
# the best bestThreshold is: 73.715
# the best bestThreshold gain is: 0.07305149618558426
# 90
# 336
# the best bestThreshold is: 73.77000000000001
# the best bestThreshold gain is: 0.07419168112482932
# 91
# 335
# the best bestThreshold is: 73.845
# the best bestThreshold gain is: 0.07533873866246915
# 92
# 334
# the best bestThreshold is: 73.905
# the best bestThreshold gain is: 0.07649272838537574
# 93
# 333
# the best bestThreshold is: 73.96000000000001
# the best bestThreshold gain is: 0.07765371068863086
# 94
# 332
# the best bestThreshold is: 74.095
# the best bestThreshold gain is: 0.07882174678276432
# 95
# 331
# the best bestThreshold is: 74.215
# the best bestThreshold gain is: 0.07999689870143861
# 96
# 330
# the best bestThreshold is: 74.28
# the best bestThreshold gain is: 0.08117922930956062
# 97
# 329
# the best bestThreshold is: 74.33500000000001
# the best bestThreshold gain is: 0.08236880231181493
# 98
# 328
# the best bestThreshold is: 74.43
# the best bestThreshold gain is: 0.08356568226160221
# 99
# 327
# the best bestThreshold is: 74.6
# the best bestThreshold gain is: 0.08476993457037829
# 100
# 326
# the best bestThreshold is: 74.775
# the best bestThreshold gain is: 0.0859816255173832
# 101
# 325
# the best bestThreshold is: 74.935
# the best bestThreshold gain is: 0.08720082225975484
# 102
# 324
# the best bestThreshold is: 74.935
# the best bestThreshold gain is: 0.08720082225975484
# 103
# 323
# the best bestThreshold is: 74.935
# the best bestThreshold gain is: 0.08720082225975484
# 104
# 322
# the best bestThreshold is: 74.935
# the best bestThreshold gain is: 0.08720082225975484
# 105
# 321
# the best bestThreshold is: 75.235
# the best bestThreshold gain is: 0.08753651300987447
# 106
# 320
# the best bestThreshold is: 75.36
# the best bestThreshold gain is: 0.08877704006392867
# 107
# 319
# the best bestThreshold is: 75.475
# the best bestThreshold gain is: 0.0900254394787749
# 108
# 318
# the best bestThreshold is: 75.5
# the best bestThreshold gain is: 0.09128178288142058
# 109
# 317
# the best bestThreshold is: 75.61
# the best bestThreshold gain is: 0.0925461428998906
# 110
# 316
# the best bestThreshold is: 75.9
# the best bestThreshold gain is: 0.0938185931746332
# 111
# 315
# the best bestThreshold is: 76.095
# the best bestThreshold gain is: 0.09509920837038477
# 112
# 314
# the best bestThreshold is: 76.205
# the best bestThreshold gain is: 0.09638806418848611
# 113
# 313
# the best bestThreshold is: 76.345
# the best bestThreshold gain is: 0.0976852373796483
# 114
# 312
# the best bestThreshold is: 76.38499999999999
# the best bestThreshold gain is: 0.09899080575716379
# 115
# 311
# the best bestThreshold is: 76.525
# the best bestThreshold gain is: 0.10030484821056196
# 116
# 310
# the best bestThreshold is: 76.715
# the best bestThreshold gain is: 0.10162744471970553
# 117
# 309
# the best bestThreshold is: 76.8
# the best bestThreshold gain is: 0.10295867636933037
# 118
# 308
# the best bestThreshold is: 76.83500000000001
# the best bestThreshold gain is: 0.10429862536402468
# 119
# 307
# the best bestThreshold is: 76.845
# the best bestThreshold gain is: 0.10564737504365229
# 120
# 306
# the best bestThreshold is: 76.9
# the best bestThreshold gain is: 0.10700500989921846
# 121
# 305
# the best bestThreshold is: 77.09
# the best bestThreshold gain is: 0.10837161558918273
# 122
# 304
# the best bestThreshold is: 77.24000000000001
# the best bestThreshold gain is: 0.10974727895621739
# 123
# 303
# the best bestThreshold is: 77.285
# the best bestThreshold gain is: 0.11113208804442071
# 124
# 302
# the best bestThreshold is: 77.37
# the best bestThreshold gain is: 0.11252613211698259
# 125
# 301
# the best bestThreshold is: 77.515
# the best bestThreshold gain is: 0.11392950167431065
# 126
# 300
# the best bestThreshold is: 77.7
# the best bestThreshold gain is: 0.1153422884726199
# 127
# 299
# the best bestThreshold is: 77.81
# the best bestThreshold gain is: 0.11676458554299218
# 128
# 298
# the best bestThreshold is: 77.85
# the best bestThreshold gain is: 0.11819648721091092
# 129
# 297
# the best bestThreshold is: 77.875
# the best bestThreshold gain is: 0.11963808911627499
# 130
# 296
# the best bestThreshold is: 77.905
# the best bestThreshold gain is: 0.12108948823390403
# 131
# 295
# the best bestThreshold is: 77.905
# the best bestThreshold gain is: 0.12108948823390403
# 132
# 294
# the best bestThreshold is: 77.905
# the best bestThreshold gain is: 0.12108948823390403
# 133
# 293
# the best bestThreshold is: 77.905
# the best bestThreshold gain is: 0.12108948823390403
# 134
# 292
# the best bestThreshold is: 78.14500000000001
# the best bestThreshold gain is: 0.12195056760286371
# 135
# 291
# the best bestThreshold is: 78.23500000000001
# the best bestThreshold gain is: 0.12343246117486362
# 135
# 291
# the best bestThreshold is: 78.23500000000001
# the best bestThreshold gain is: 0.12343246117486362
# 137
# 289
# the best bestThreshold is: 78.445
# the best bestThreshold gain is: 0.1264272823429296
# 138
# 288
# the best bestThreshold is: 78.60499999999999
# the best bestThreshold gain is: 0.12794042155452506
# 139
# 287
# the best bestThreshold is: 78.68
# the best bestThreshold gain is: 0.12946419014645172
# 140
# 286
# the best bestThreshold is: 78.765
# the best bestThreshold gain is: 0.13099869779100087
# 141
# 285
# the best bestThreshold is: 78.805
# the best bestThreshold gain is: 0.13254405575167044
# 141
# 285
# the best bestThreshold is: 78.805
# the best bestThreshold gain is: 0.13254405575167044
# 143
# 283
# the best bestThreshold is: 78.84
# the best bestThreshold gain is: 0.13566777578909894
# 144
# 282
# the best bestThreshold is: 78.91999999999999
# the best bestThreshold gain is: 0.1372463685876677
# 145
# 281
# the best bestThreshold is: 78.91999999999999
# the best bestThreshold gain is: 0.1372463685876677
# 146
# 280
# the best bestThreshold is: 78.91999999999999
# the best bestThreshold gain is: 0.1372463685876677
# 147
# 279
# the best bestThreshold is: 78.91999999999999
# the best bestThreshold gain is: 0.1372463685876677
# 148
# 278
# the best bestThreshold is: 79.33
# the best bestThreshold gain is: 0.13843821708075837
# 149
# 277
# the best bestThreshold is: 79.625
# the best bestThreshold gain is: 0.1400527305970144
# 150
# 276
# the best bestThreshold is: 79.805
# the best bestThreshold gain is: 0.1416790530212642
# 151
# 275
# the best bestThreshold is: 80.13
# the best bestThreshold gain is: 0.14331731099386003
# 152
# 274
# the best bestThreshold is: 80.525
# the best bestThreshold gain is: 0.14496763306160326
# 153
# 273
# the best bestThreshold is: 80.75
# the best bestThreshold gain is: 0.14663014971077093
# 154
# 272
# the best bestThreshold is: 80.93
# the best bestThreshold gain is: 0.148304993400942
# 155
# 271
# the best bestThreshold is: 81.065
# the best bestThreshold gain is: 0.14999229859964391
# 156
# 270
# the best bestThreshold is: 81.065
# the best bestThreshold gain is: 0.14999229859964391
# 156
# 270
# the best bestThreshold is: 81.065
# the best bestThreshold gain is: 0.14999229859964391
# 158
# 268
# the best bestThreshold is: 81.065
# the best bestThreshold gain is: 0.14999229859964391
# 159
# 267
# the best bestThreshold is: 81.32
# the best bestThreshold gain is: 0.15147900844619588
# 159
# 267
# the best bestThreshold is: 81.32
# the best bestThreshold gain is: 0.15147900844619588
# 161
# 265
# the best bestThreshold is: 81.36
# the best bestThreshold gain is: 0.154948561604988
# 162
# 264
# the best bestThreshold is: 81.545
# the best bestThreshold gain is: 0.15670324884766462
# 163
# 263
# the best bestThreshold is: 81.545
# the best bestThreshold gain is: 0.15670324884766462
# 164
# 262
# the best bestThreshold is: 81.545
# the best bestThreshold gain is: 0.15670324884766462
# 165
# 261
# the best bestThreshold is: 81.545
# the best bestThreshold gain is: 0.15670324884766462
# 166
# 260
# the best bestThreshold is: 82.44
# the best bestThreshold gain is: 0.15839349033936556
# 167
# 259
# the best bestThreshold is: 82.505
# the best bestThreshold gain is: 0.16019236210316062
# 168
# 258
# the best bestThreshold is: 82.53999999999999
# the best bestThreshold gain is: 0.16200534172755
# 169
# 257
# the best bestThreshold is: 82.53999999999999
# the best bestThreshold gain is: 0.16200534172755
# 169
# 257
# the best bestThreshold is: 82.53999999999999
# the best bestThreshold gain is: 0.16200534172755
# 169
# 257
# the best bestThreshold is: 82.53999999999999
# the best bestThreshold gain is: 0.16200534172755
# 172
# 254
# the best bestThreshold is: 82.62
# the best bestThreshold gain is: 0.1638778097244057
# 173
# 253
# the best bestThreshold is: 82.65
# the best bestThreshold gain is: 0.16573798976882337
# 174
# 252
# the best bestThreshold is: 82.68
# the best bestThreshold gain is: 0.16761312935443684
# 175
# 251
# the best bestThreshold is: 82.755
# the best bestThreshold gain is: 0.16950340390358543
# 176
# 250
# the best bestThreshold is: 83.0
# the best bestThreshold gain is: 0.1714089917224217
# 177
# 249
# the best bestThreshold is: 83.185
# the best bestThreshold gain is: 0.1733300740566342
# 178
# 248
# the best bestThreshold is: 83.35
# the best bestThreshold gain is: 0.17526683514859204
# 179
# 247
# the best bestThreshold is: 83.625
# the best bestThreshold gain is: 0.1772194622959486
# 180
# 246
# the best bestThreshold is: 83.85499999999999
# the best bestThreshold gain is: 0.1791881459117441
# 181
# 245
# the best bestThreshold is: 83.85499999999999
# the best bestThreshold gain is: 0.1791881459117441
# 182
# 244
# the best bestThreshold is: 83.85499999999999
# the best bestThreshold gain is: 0.1791881459117441
# 182
# 244
# the best bestThreshold is: 83.85499999999999
# the best bestThreshold gain is: 0.1791881459117441
# 184
# 242
# the best bestThreshold is: 84.09
# the best bestThreshold gain is: 0.18147248081363443
# 185
# 241
# the best bestThreshold is: 84.115
# the best bestThreshold gain is: 0.18349639271754292
# 186
# 240
# the best bestThreshold is: 84.155
# the best bestThreshold gain is: 0.18553738377562068
# 187
# 239
# the best bestThreshold is: 84.23
# the best bestThreshold gain is: 0.18759566493557567
# 188
# 238
# the best bestThreshold is: 84.36500000000001
# the best bestThreshold gain is: 0.1896714507638474
# 189
# 237
# the best bestThreshold is: 84.485
# the best bestThreshold gain is: 0.19176495952000105
# 190
# 236
# the best bestThreshold is: 84.535
# the best bestThreshold gain is: 0.19387641323307658
# 191
# 235
# the best bestThreshold is: 84.645
# the best bestThreshold gain is: 0.1960060377799449
# 192
# 234
# the best bestThreshold is: 84.81
# the best bestThreshold gain is: 0.1981540629657323
# 193
# 233
# the best bestThreshold is: 84.91499999999999
# the best bestThreshold gain is: 0.2003207226063719
# 194
# 232
# the best bestThreshold is: 85.02000000000001
# the best bestThreshold gain is: 0.2025062546133437
# 195
# 231
# the best bestThreshold is: 85.16499999999999
# the best bestThreshold gain is: 0.20471090108066914
# 196
# 230
# the best bestThreshold is: 85.25
# the best bestThreshold gain is: 0.206934908374224
# 197
# 229
# the best bestThreshold is: 85.25
# the best bestThreshold gain is: 0.206934908374224
# 198
# 228
# the best bestThreshold is: 85.25
# the best bestThreshold gain is: 0.206934908374224
# 199
# 227
# the best bestThreshold is: 85.555
# the best bestThreshold gain is: 0.20761765125817772
# 200
# 226
# the best bestThreshold is: 85.66
# the best bestThreshold gain is: 0.20989040311920132
# 201
# 225
# the best bestThreshold is: 85.78999999999999
# the best bestThreshold gain is: 0.21218357944676763
# 202
# 224
# the best bestThreshold is: 85.935
# the best bestThreshold gain is: 0.21449745046769253
# 203
# 223
# the best bestThreshold is: 85.935
# the best bestThreshold gain is: 0.21449745046769253
# 204
# 222
# the best bestThreshold is: 85.935
# the best bestThreshold gain is: 0.21449745046769253
# 205
# 221
# the best bestThreshold is: 86.54499999999999
# the best bestThreshold gain is: 0.2153552085786956
# 206
# 220
# the best bestThreshold is: 86.88
# the best bestThreshold gain is: 0.217721908943311
# 207
# 219
# the best bestThreshold is: 87.175
# the best bestThreshold gain is: 0.2201104758289506
# 208
# 218
# the best bestThreshold is: 87.19999999999999
# the best bestThreshold gain is: 0.22252120648788615
# 208
# 218
# the best bestThreshold is: 87.19999999999999
# the best bestThreshold gain is: 0.22252120648788615
# 210
# 216
# the best bestThreshold is: 87.19999999999999
# the best bestThreshold gain is: 0.22252120648788615
# 211
# 215
# the best bestThreshold is: 87.35
# the best bestThreshold gain is: 0.22356638968372938
# 212
# 214
# the best bestThreshold is: 87.41999999999999
# the best bestThreshold gain is: 0.22603450856564594
# 213
# 213
# the best bestThreshold is: 87.47999999999999
# the best bestThreshold gain is: 0.22852608609402902
# 214
# 212
# the best bestThreshold is: 87.47999999999999
# the best bestThreshold gain is: 0.22852608609402902
# 214
# 212
# the best bestThreshold is: 87.47999999999999
# the best bestThreshold gain is: 0.22852608609402902
# 216
# 210
# the best bestThreshold is: 87.80000000000001
# the best bestThreshold gain is: 0.22973543749018194
# 217
# 209
# the best bestThreshold is: 87.86
# the best bestThreshold gain is: 0.23228842172115155
# 218
# 208
# the best bestThreshold is: 87.895
# the best bestThreshold gain is: 0.23486627194058823
# 219
# 207
# the best bestThreshold is: 88.005
# the best bestThreshold gain is: 0.23746934414705861
# 220
# 206
# the best bestThreshold is: 88.11
# the best bestThreshold gain is: 0.24009800133171022
# 221
# 205
# the best bestThreshold is: 88.245
# the best bestThreshold gain is: 0.2427526136470043
# 221
# 205
# the best bestThreshold is: 88.245
# the best bestThreshold gain is: 0.2427526136470043
# 223
# 203
# the best bestThreshold is: 88.385
# the best bestThreshold gain is: 0.2481412211335822
# 224
# 202
# the best bestThreshold is: 88.385
# the best bestThreshold gain is: 0.2481412211335822
# 225
# 201
# the best bestThreshold is: 88.385
# the best bestThreshold gain is: 0.2481412211335822
# 226
# 200
# the best bestThreshold is: 88.61500000000001
# the best bestThreshold gain is: 0.24973584746670224
# 227
# 199
# the best bestThreshold is: 88.61500000000001
# the best bestThreshold gain is: 0.24973584746670224
# 228
# 198
# the best bestThreshold is: 88.61500000000001
# the best bestThreshold gain is: 0.24973584746670224
# 229
# 197
# the best bestThreshold is: 89.525
# the best bestThreshold gain is: 0.2514386046565439
# 230
# 196
# the best bestThreshold is: 89.67
# the best bestThreshold gain is: 0.25426485076146677
# 231
# 195
# the best bestThreshold is: 89.75999999999999
# the best bestThreshold gain is: 0.2571204633493862
# 232
# 194
# the best bestThreshold is: 89.9
# the best bestThreshold gain is: 0.26000589161058485
# 233
# 193
# the best bestThreshold is: 90.16499999999999
# the best bestThreshold gain is: 0.26292159413007254
# 234
# 192
# the best bestThreshold is: 90.305
# the best bestThreshold gain is: 0.2658680391304127
# 235
# 191
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 236
# 190
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 237
# 189
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 238
# 188
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 239
# 187
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 240
# 186
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 241
# 185
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 242
# 184
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 243
# 183
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 244
# 182
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 245
# 181
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 246
# 180
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 247
# 179
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 248
# 178
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 249
# 177
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 250
# 176
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 251
# 175
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 252
# 174
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 253
# 173
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 254
# 172
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 254
# 172
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 256
# 170
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 257
# 169
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 258
# 168
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 259
# 167
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 260
# 166
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 261
# 165
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 262
# 164
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 263
# 163
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 264
# 162
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 265
# 161
# the best bestThreshold is: 90.37
# the best bestThreshold gain is: 0.2688457047222247
# 266
# 160
# the best bestThreshold is: 95.52000000000001
# the best bestThreshold gain is: 0.2707248028571727
# 267
# 159
# the best bestThreshold is: 95.52000000000001
# the best bestThreshold gain is: 0.2707248028571727
# 268
# 158
# the best bestThreshold is: 95.52000000000001
# the best bestThreshold gain is: 0.2707248028571727
# 269
# 157
# the best bestThreshold is: 95.52000000000001
# the best bestThreshold gain is: 0.2707248028571727
# 270
# 156
# the best bestThreshold is: 95.52000000000001
# the best bestThreshold gain is: 0.2707248028571727
# 271
# 155
# the best bestThreshold is: 95.955
# the best bestThreshold gain is: 0.27409824842788366
# 272
# 154
# the best bestThreshold is: 96.075
# the best bestThreshold gain is: 0.27772859382702786
# 273
# 153
# the best bestThreshold is: 96.17
# the best bestThreshold gain is: 0.2814076432289438
# 274
# 152
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 275
# 151
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 276
# 150
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 277
# 149
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 278
# 148
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 278
# 148
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 280
# 146
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 281
# 145
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 282
# 144
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 283
# 143
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 284
# 142
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 285
# 141
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 286
# 140
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 287
# 139
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 288
# 138
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 289
# 137
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 290
# 136
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 291
# 135
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 292
# 134
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 293
# 133
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 294
# 132
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 295
# 131
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 296
# 130
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 297
# 129
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 298
# 128
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 299
# 127
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 300
# 126
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 300
# 126
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 302
# 124
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 303
# 123
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 304
# 122
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 305
# 121
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 306
# 120
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 307
# 119
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 308
# 118
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 309
# 117
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 310
# 116
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 311
# 115
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 312
# 114
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 313
# 113
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 314
# 112
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 315
# 111
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 316
# 110
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 317
# 109
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 318
# 108
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 319
# 107
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 319
# 107
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 321
# 105
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 322
# 104
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 323
# 103
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 324
# 102
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 325
# 101
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 326
# 100
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 327
# 99
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 328
# 98
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 329
# 97
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 330
# 96
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 331
# 95
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 332
# 94
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 333
# 93
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 334
# 92
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 335
# 91
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 335
# 91
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 337
# 89
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 337
# 89
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 339
# 87
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 340
# 86
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 341
# 85
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 342
# 84
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 343
# 83
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 344
# 82
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 345
# 81
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 346
# 80
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 347
# 79
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 347
# 79
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 349
# 77
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 350
# 76
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 351
# 75
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 352
# 74
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 353
# 73
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 354
# 72
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 355
# 71
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 356
# 70
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 357
# 69
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 358
# 68
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 359
# 67
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 360
# 66
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 361
# 65
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 362
# 64
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 363
# 63
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 364
# 62
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 365
# 61
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 365
# 61
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 367
# 59
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 368
# 58
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 369
# 57
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 370
# 56
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 371
# 55
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 372
# 54
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 373
# 53
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 374
# 52
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 375
# 51
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 376
# 50
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 377
# 49
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 378
# 48
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 379
# 47
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 380
# 46
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 380
# 46
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 382
# 44
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 383
# 43
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 384
# 42
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 385
# 41
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 386
# 40
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 387
# 39
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 388
# 38
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 389
# 37
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 390
# 36
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 390
# 36
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 392
# 34
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 393
# 33
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 393
# 33
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 395
# 31
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 396
# 30
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 397
# 29
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 397
# 29
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 399
# 27
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 399
# 27
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 401
# 25
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 402
# 24
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 403
# 23
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 404
# 22
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 405
# 21
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 405
# 21
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 407
# 19
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 408
# 18
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 409
# 17
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 410
# 16
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 411
# 15
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 412
# 14
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 413
# 13
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 414
# 12
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 415
# 11
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 416
# 10
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 417
# 9
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 418
# 8
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 419
# 7
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 420
# 6
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 421
# 5
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 422
# 4
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 423
# 3
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 424
# 2
# the best bestThreshold is: 96.32
# the best bestThreshold gain is: 0.28513634413712285
# 425
# 1
# 96.32

# %% [markdown]
# ## Tree evaluation
#
# Complete the functions `predict` and `calc_accuracy` in the python file `hw2.py`. You are allowed to implement this functionality as a class method.
#
# After building both trees using the training set (using Gini and Entropy as impurity measures), you should calculate the accuracy on the test set and print the measure that gave you the best test accuracy. For the rest of the exercise, use that impurity measure. (10 points)

# %%
#### Your code here ####

# %% [markdown]
# ## Chi square pre-pruning
#
# Consider the following p-value cut-off values: [1 (no pruning), 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00001]. For each value, construct a tree and prune it according to the cut-off value. Next, calculate the training and testing accuracy. On a single plot, draw the training and testing accuracy as a function of the p-value. What p-value gives you the best results? Does the results support the theory you learned in class regarding Chi square pruning? Explain. (20 points)
#
# **Note**: You need to change the `DecisionNode` to support Chi square pruning. Make sure the `chi_value=1` corresponds to no pruning. The values you need from the Chi square table are available in the python file `hw2.py`.

# %%
training = []
testing  = []

#### Your code here ####
for chi_value in [1, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00001]:
    pass

# %%
#### Your visualization here ####

# %% [markdown]
# Your answer here

# %% [markdown]
# ## Post pruning
#
# Construct a decision tree without Chi square pruning. For each leaf in the tree, calculate the test accuracy of the tree assuming no split occurred on the parent of that leaf and find the best such parent (in the sense that not splitting on that parent results in the best testing accuracy among possible parents). Make that parent into a leaf and repeat this process until you are left with just the root. On a single plot, draw the training and testing accuracy as a function of the number of internal nodes in the tree. Explain the results: what would happen to the training and testing accuracies when you remove nodes from the tree? Can you suggest a different approach to achieve better results? (20 points)

# %%
#### Your code here ####

# %% [markdown]
# Your answer here

# %% [markdown]
# ## Print the tree
#
# Complete the function `print_tree` in the python file `hw2.py` and print the tree using the chosen impurity measure and no pruning. Your code should like something like this (10 points):
# ```
# [X0 <= 1],
#   [X1 <= 2]
#     [X2 <= 3],
#        leaf: [{1.0: 10}]
#        leaf: [{0.0: 10}]
#     [X4 <= 5],
#        leaf: [{1.0: 5}]
#        leaf: [{0.0: 10}]
#    leaf: [{1.0: 50}]
# ```

# %%
#### Your code here ####
